# %% [markdown]
# # 使用appnium和路路通移动版获取时刻表
# <b>实际上在开发中appnium已经不在维护且配置较为困难,仅离线使用</b>
# 下次会退回重新使用selenium
#
# ## 当前状态
# - 主要由于路路通相较于12306在时刻表层面提供更多的信息
#     - 如停到站时间及始发终到等信息丰富,车站大屏由于网络问题不好使用
#     - 而路路通网页版不提供此类信息(12306不太好作),难以使用web自动化爬取
#     - 这里使用appnium和模拟器来获得数据,但是配置较为复杂
#     - 检票口(映射股道)需要依照车次再次查询如网页版12306或是这里的车次查询
#
# - 目前爬取效果,处理等和前面武汉枢纽相同
#     - 基本实现自动化,但是由于车站和车次页面不同,需要手动切换分辨率,也可以开始时直接拉满防止画面溢出,目前暂时不知道更好的方法
#     - 目前重点为完善车次爬取部分改为获取停站的上一站和下一站,可以解决进路冲突的问题如 济南东→济南西 和 济南→济南西 均为上行导致无法区分并获取更详细的信息
#     - 完善度表格:    <br>
#
# |组件信息|完善程度|当前状态|日后计划|
# |---|---|---|---|
# 车站|整体较为成熟完善|可以按照单一地区车站模糊匹配,精确匹配后续筛选|暂无
# 车次|信息较为完善但是观感不佳|可以获得单一车次给出的大部分信息如停站检票口等.<br>主要为从车次查询-检票口查询获得|考虑压缩为字典样式以更好的存储信息
# 检票口/股道 | 不完善，需要二次处理|如不需要车站爬取可以直接由单个车站获得足够信息,<br>无需经过查询车次继续处理。若需要检票口信息需要在获取完成车站的车次信息后再查询检票口|完善筛选逻辑
# 立折车辆 | 纯手动，没有处理|手动查找修改|计划在日后由车次部分下交路表完成|计划在车次查询部分加上交路表部分信息获取
# 越行车辆 |纯手动，完全没有处理|没有计划|不知道怎么获知越行车信息
#
# ## 使用的库函数信息和达成的基本效果
# <b>主要为了提高复用性功能大体分为了三个部分，数据处理可以单独由excel或csv使用无需使用爬虫</b>
# - 获取整体信息-自动化爬虫部分
#     - appnium的APP自动化。<b>实际上在开发中appnium已经不在维护,仅离线使用</b>
#     - 一般的io文本处理部分，输出为csv样式的txt文本文件
# - 初步信息处理-数据处理/数据分析
#     - 整理出较为规整的数据，主要按照车次来汇总数据便于后续操作
#     - 输出符合游戏地图要求的时刻表信息或是进行其他分析
# - 没啥用的可视化
#     - 主要是pyecharts，输出一些可交互的图片更为直观
#
# ----
# ## 第一部分，定义使用的库函数和常量信息
# ### 内容
# 库函数主要分为三大部分：获取数据--处理数据--<del>分析（可视化）数据</del>。即下面引用部分大体分为了三部分
# 而常量部分主要用于处理数据生成符合游戏格式的时刻表，这部分会随着函数的完善而更为精简
# 以及最后的模拟器信息用于appnium连接模拟器获取路路通信息
# ### 待完善/优化的部分
# 1. 编组映射待交路表信息获取完成后会按照车型映射如长编和重连，即使用下面marshalling字典
# 2. 速度等级也会按照车型信息重新映射
# 3. 建立进场路径映射相关常量来完善分场式车站可能的调度问题，提高调度自动化程度
# 4. .....

# %%
import appium  # app自动化使用，获取信息
from appium import webdriver
from appium.webdriver.webdriver import WebDriver
from appium.webdriver.common.appiumby import AppiumBy
from appium.webdriver.extensions.android.nativekey import AndroidKey
from appium.webdriver.common.touch_action import TouchAction
import time

import pandas

# 数据分析/数据可视化使用
import matplotlib
import pyecharts
import plotly.figure_factory as ff
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline


trainType = ["普客", "新空调快速", "新空调特快", "新空调直快", "动车", "高速", "城际"]
stationRegion = ["济南", "济南西", "济南东", "大明湖"]


Excelpath = "data.xlsx"  # Excel时刻表输入文件路径，如爬取的时刻表或是是复制来的
TextPath = "train.txt"  # 游戏时刻表文件输出路径
# 速度和编组以及类型映射关系,0为普速1为动车2为高速，后续修改
species = {'新空调普快': ['120', 'LPPPPPP', 0], '新空调快速': ['120', 'LPPPPPP', 0],
           '新空调特快': ['140', 'LPPPPPP', 0], '新空调直快': ['160', 'LPPPPPP', 0],
           '动车': ['200', 'LPPL', 1], '城际': ['200', 'LPPL', 1], '高速': ['300', 'LPPLLPPL', 2]}
species1 = {'K': ['120', 'LPPPPPP', 0], 'T': ['140', 'LPPPPPP', 0], 'Z': ['160', 'LPPPPPP', 0],
            'D': ['200', 'LPPL', 1], 'C': ['200', 'LPPL', 1], 'G': ['300', 'LPPLLPPL', 2]}

# 车站-编号,掉向,用时以及运行车辆种类映射关系
# 图片左(0)右(1)侧线路key值相同则掉向,
# 国铁车辆行走左侧,2为数据为左侧股道编号
# [车站编号,车站所在侧(0为左侧),车辆进场股道,车辆离场行走股道,到达中心车站所用时间]
station = {
    '京济联络线济南方向': ['b', 0, 2, 1, 8], '济郑高速长清方向': ['c', 0, 2, 1, 7],
    '济南西站': ['d', -1, 0, 0, 7], '济南西动车所': ['e', -1, 0, 0, 30],
    '京沪高速德州东方向': ['f', 1, '1', '2', 6, ], '京沪高速泰安站方向': ['a', 0, 2, 1, 7, ],
    '石济客专齐河方向': ['g', 1, 1, 2, 6], '石济客专济南东方向': ['h', 1, 1, 2, 6, ],
}

# 线路和车站关系，主要用于从车站-值获取线路-键
route1 = {
    '济南西动车所': ["济南西"], '京济联络线济南方向': ["济南"], '济郑高速长清方向': ["长清"],
    '京沪高速泰安站方向': ["泰安", "曲阜东", "滕州东", "枣庄", "徐州东", "宿州东", "蚌埠南", "南京南"],
    '京沪高速德州东方向': ["北京南", "天津西", "天津", "沧州西", "德州东"],
    '石济客专齐河方向': ["齐河", "禹城东", "平原东"], '石济客专济南东方向': ["济南东"]}
# 两个合在一起写太难看


# 车型关系--待完善，后续待交路表部分完成后会使用对应映射而不是上面的简单类型映射
marshalling = {'CHR380BL': [], 'CHR380B': [], 'CHR380B重连': []}


ThisStation = '济南西站'
TotalPlat = 18
# track = {}


# 模拟器信息
desired_caps = {
    'platformName': 'Android',  # 被测手机是安卓
    'platformVersion': '9',  # 手机安卓版本
    'deviceName': 'emulator-5554:5555',  # 设备名和映射连接端口，安卓手机可以随意填写

    'appPackage': 'com.lltskb.lltskb',  # 启动APP Package名称
    'appActivity': '.ui.splash.SplashActivity',  # 启动Activity名称

    'unicodeKeyboard': True,  # 使用自带输入法，输入中文时填True
    'resetKeyboard': True,  # 执行完程序恢复原来输入法
    'noReset': True,       # 不要重置App
    'newCommandTimeout': 6000,
    'automationName': 'UiAutomator2'
}

# %% [markdown]
# ## 第二部分，appnium自动化爬取路路通上时刻表信息
# ### 内容
# 这部分主要有三个函数，分别是按照车站获取车次信息，按照车次查询--检票口查询获取该车次所有信息，以及车站大屏查询
# 数据均来自路路通，界面信息所见即所得
# 1. 车站信息
#     1.1 这部分较为简单，爬取时信息较为规整。始发终到车站信息等界面上每一个格子都对应一个数据，按照正常顺序获取处理即可
#     1.2 滑动页面并获取数据，数据按照一行八个获取，以csv样式写入txt
# 2. 车次信息--检票样式查询
#     2.1 这部分难度就大很多，主要难点在于目前来看必须多次重复点击查询按钮
#     2.2 同样滑动页面并获取数据，数据按照以车站核心一行四个数据，同样以csv样式写入文本txt
# 3. 车站大屏信息
#     3.1 由于网络问题应该相当长的时间内无法完成，主要目的是为了获取如汉口站，郑州站这类检票口信息不定导致无法离线查询的车站
#
# ### 效果
# 1. 如果不需要做进路映射和股道映射，单纯通过车站信息爬取已经足够使用，已经有完善的实发终到，到时开时信息
# 2. 如果需要做进路映射和股道映射且较为复杂，可以用后面车次信息部分来获取这部分信息，但是时长较大
#
# ### 实现原理
# 1. appnium按流程进入页面并得到文本数据
# 2. 死循环获取页面数据，直到页面数据不在变化或者由于数据过少而无法变化直接退出
# 3. 使用set来收集数据以优化重复数据
#
# ### 待完善/优化的部分
# <del>目标更换 1. 优化车次信息查询逻辑，改善输入格式，进行多轮查询时可以更好的数据结果，为之后按照车次来部署整条线路做准备</del>
# 1. 优化车次信息查询效率，尽可能少重复点选
# 2. 加入点击交路表并获取相关信息的部分，使得立折车次自动合并和正确映射编组成为可能
# 3. 看看能不能使用车站大屏功能，可以获取停站股道不定的车站检票口停站信息
# 4. .......

# %%
# 每一个车站的所有停车信息

def StationTrainList(driver: WebDriver, action: TouchAction, station: str):
    time.sleep(8)  # 等待开屏广告
    stationText = driver.find_element(
        AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().text("车站")')

    action.tap(stationText).perform()  # 点击车站选项的位置

    stationChk = driver.find_element(
        AppiumBy.ID, "com.lltskb.lltskb:id/layout_station")  # 车站选择部分
    action.tap(stationChk).perform()  # 进入车站选择
    time.sleep(1)
    stationSelect = driver.find_element(
        AppiumBy.ID, "com.lltskb.lltskb:id/edit_input")  # 车站选择输入框
    stationSelect.send_keys(station)  # 输入

    stationFind = driver.find_elements(
        AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().text("{0}")'.format(station))
    action.tap(stationFind[1]).perform()  # 输入车站名并确认，返回之前的页面

    searchbtn = driver.find_element(
        AppiumBy.ID, "com.lltskb.lltskb:id/querycz_btn")  # 搜索按钮
    action.tap(searchbtn).perform()  # 点选进行查找
    time.sleep(2)
    # 当前页面可视的车次部分
    pt = driver.find_element(AppiumBy.CLASS_NAME, 'android.widget.ListView')
    x1 = pt.size['width'] * 0.5
    y1 = pt.size['height']  # 获取页面宽高,方便后续滑动截取车次信息

    f = open(file="{0}Info.txt".format(station), mode="w", encoding="utf-8")
    # 设置为utf8，防止如复兴号，静音动车等符号导致报错
    settext = set()  # 使用set尽可能减少重复值

    while True:  # 滑动截取文字
        # 所有有文本的元素的集合，均为当前可见部分
        pageTrainList = driver.find_elements(
            AppiumBy.CLASS_NAME, 'android.widget.TextView')
        beforeSwipe = driver.page_source

        text = ""
        for i in range(0, len(pageTrainList)-9):  # 排除表头信息，仅保留车次部分
            text = text+pageTrainList[i+9].text+","  # 获取整体信息
            if (i+9) % 8 == 0:

                settext.add(text+"\n")
                text = ""

        try:
            # 这里模拟器的分辨率是1920*1080的手机屏幕，不一样的需要改参数
            # 如果内容少于一屏幕会直接报错，故使用try
            action.long_press(
                x=540, y=1800, duration=200).move_to(x=540, y=100).release()
            action.perform()  # 在中间滑动，选取新的车次信息
        # 如果滑动前后的元素相同，则表示已经到底了
        except Exception:  # 少于一屏幕就表示已经完成了
            break
        else:  # 前后的页面元素一样
            if driver.page_source == beforeSwipe:
                break
    for it in settext:
        f.write(it)
    f.close()

    return

# 一组一列车的所有停站信息


def TrainStationList(driver: WebDriver, action: TouchAction, trainli: list[str], fn="appniumTrainInfo.txt"):
    time.sleep(8)  # 等待开屏广告
    stationText = driver.find_element(
        AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().text("车次")')
    action.tap(stationText).perform()  # 点击车次选项的位置

    stationchk = driver.find_element(
        AppiumBy.ID, "com.lltskb.lltskb:id/chk_jpk")
    action.tap(stationchk).perform()  # 点选查找检票口选项
    # 设置为utf8，防止如复兴号，静音动车等符号导致报错
    f = open(file=fn, mode="w", encoding="utf-8")
    for train in trainli:
        settext = set()  # 使用set尽可能减少重复值
        btnClicked = []
        trainSelect = driver.find_element(
            AppiumBy.ID, "com.lltskb.lltskb:id/edit_train")
        trainSelect.clear()  # 清空内容防止重输
        trainSelect.send_keys(train)  # 输入查找车次

        searchbtn = driver.find_element(
            AppiumBy.ID, "com.lltskb.lltskb:id/querycc_btn")  # 搜索按钮
        action.tap(searchbtn).perform()  # 点选进行查找

        text = ""
        while True:  # 进入页面
            searchbtns = driver.find_elements(
                AppiumBy.ID, "com.lltskb.lltskb:id/btn_query")  # 搜索按钮
            beforeSwipe = driver.page_source

            for btn in searchbtns:  # 当前页面上所有“查询”按钮，目前除了全部重复点一遍没有好办法
                # if btn.id in btnClicked:
                #     continue
                action.tap(btn).perform()  # 点选所有按钮进行查找
                btnClicked.append(btn.id)  # 只能用列表等来标记

            pageStationList = driver.find_elements(
                AppiumBy.CLASS_NAME, 'android.widget.TextView')
           # 获取页面所有信息
            for i in range(1, len(pageStationList)):
                # 停站，到时，开时，检票口共四个停站信息
                text = text+pageStationList[i].text+","
                if i % 4 == 0:  # 每一个车站
                    text = train+","+text+"\n"
                    settext.add(text)
                    text = ""
            try:
                # 这里模拟器的分辨率是1920*1080的手机屏幕
                # 如果内容少于一屏幕会直接报错，故使用try
                action.long_press(
                    x=540, y=1700, duration=150).move_to(x=540, y=200).release()
                action.perform()  # 在中间滑动，选取新的车次信息
                time.sleep(0.5)
            # 如果滑动前后的元素相同，则表示已经到底了
            except Exception:  # 少于一屏幕就表示已经完成了
                print(Exception.args)
                break
            else:  # 前后的页面元素一样
                if driver.page_source == beforeSwipe:
                    break

        # 按下返回按键，进行下一次查找
        retbtn = driver.find_element(
            AppiumBy.ID, "com.lltskb.lltskb:id/btn_back")
        action.tap(retbtn).perform()
        # 替换两个汉字，方便后续操作
        print(settext)
        for it in settext:
            it = it.replace("到", "").replace("开", "")
            f.write(it)
        f.flush()  # 直接刷新缓冲区写入

    f.close()

    return


# 未完成，车站大屏查询


def StationScreenList(driver: WebDriver, action: TouchAction, train: str):
    stationText = driver.find_element(
        AppiumBy.ANDROID_UIAUTOMATOR, 'new UiSelector().text("车站")')

    action.tap(stationText).perform()  # 点击车站选项的位置

    stationChk = driver.find_element(
        AppiumBy.ID, "com.lltskb.lltskb:id/btn_big_screen")  # 车站大屏选择
    action.tap(stationChk).perform()  # 车站大屏内容部分

    return

# %% [markdown]
# <b> 爬取部分无需多次运行 </b>

# %%
driver = webdriver.Remote('http://localhost:4723/wd/hub', desired_caps)
# 设置缺省等待时间
driver.implicitly_wait(10)
action = TouchAction(driver)  # 点选操作的对象

targetSt = "济南西"
# 济南Info是之前爬取的济南地区车站信息
stationFrame = pandas.read_csv(filepath_or_buffer="济南Info1.txt",
                               sep=",", encoding="utf-8")
stationFrame.columns = ["车次", "drop1", "停站",
                        "到时", "开时", "始发站", "终到站", "列车类型", "drop2"]
# 删去重复列和空列
stationFrame.drop_duplicates(inplace=True)
stationFrame.drop(columns=["drop1", "drop2"], inplace=True)

# 获取所有济南西站的车次信息
jnzlist = stationFrame[stationFrame["停站"] == targetSt]["车次"].to_list()
TrainStationList(driver, action, jnzlist, "jinanxitest2.txt")

time.sleep(3)
# driver.close()
driver.quit()
# Out:
# {'G376,镇江南,08:56到,08:58开,无检票口信息,\n', 'G376,衡水北,13:25到,13:28开,无检票口信息,\n', 'G376,南京南,09:16到,09:20开,检票口A6,\n', 'G376,昆山南,07:49到,07:55开,检票口2,\n', 'G376,济南西,12:04到,12:07开,检票口17B,\n', 'G376,德州东,12:48到,12:51开,检票口2,\n', 'G376,苏州北,08:06到,08:20开,检票口1A,\n', 'G376,平原东,12:35到,12:37开,无检票口信息,\n', 'G376,辛集南,13:44到,13:46开,无检票口信息,\n', 'G376,泰安,11:42到,11:47开,检票口检票口1 检票口2,\n', 'G376,景州,13:07到,13:09开,无检票口信息,\n', 'G376,滁州,09:38到,09:40开,无检票口信息,\n', 'G376,上海虹桥,--:--到,07:32开,检票口7B,\n', 'G376,徐州东,10:47到,10:49开,检票口东广场进站7A7B检票,\n', 'G376,石家庄,14:14到,--:--开,无检票口信息,\n', 'G376,宿州东,10:26到,10:28开,无检票口信息,\n'}
# {'G301,德州东,11:39到,11:41开,检票口2,\n', 'G301,福州,19:49到,19:52开,检票口8检票口,\n', 'G301,无检票口信息,上饶,18:10到,18:13开,\n', 'G301,合肥北城,15:02到,15:04开,无检票口信息,\n', 'G301,延平,19:11到,19:13开,无检票口信息,\n', 'G301,曲阜东,12:42到,12:57开,无检票口信息,\n', 'G301,上饶,18:10到,18:13开,检票口一层5A号检票口,\n', 'G301,济南西,12:05到,12:10开,检票口5B,\n', 'G301,武夷山北,18:35到,18:37开,无检票口信息,\n', 'G301,无检票口信息,德兴,17:50到,17:52开,\n', 'G301,检票口1层检票,婺源,17:37到,17:39开,\n', 'G301,无检票口信息,绩溪北,16:56到,16:58开,\n', 'G301,蚌埠南,14:12到,14:14开,无检票口信息,\n', 'G301,徐州东,13:33到,13:35开,检票口东广场进站7A7B检票,\n', 'G301,厦门北,21:19到,--:--开,无检票口信息,\n', 'G301,无检票口信息,南陵,16:29到,16:31开,\n', 'G301,德兴,17:50到,17:52开,无检票口信息,\n', 'G301,淮南东,14:30到,14:32开,无检票口信息,\n', 'G301,福清西,20:23到,20:25开,无检票口信息,\n', 'G301,泉州南,20:59到,21:01开,无检票口信息,\n', 'G301,合肥北城,合肥南,15:28到,15:32开,\n', 'G301,无检票口信息,铜陵北,16:15到,16:17开,\n', 'G301,水家湖,14:41到,14:46开,无检票口信息,\n', 'G301,北京南,--:--到,10:26开,检票口17A、17B,\n', 'G301,检票口一层5A号检票口,德兴,17:50到,17:52开,无检票口信息,\n', 'G301,检票口2,黄山北,17:13到,17:16开,\n', 'G301,检票口15A,无为,16:01到,16:03开,\n', 'G301,福州南,20:06到,20:08开,检票口24/25B,\n'}
# {'G123,济南西,12:10到,12:14开,检票口7B,\n', 'G123,泰安,12:31到,12:40开,检票口检票口1 检票口2,\n', 'G123,廊坊,10:36到,10:45开,无检票口信息,\n', 'G123,南京南,14:54到,15:05开,检票口A5,\n', 'G123,无锡东,15:56到,15:58开,检票口无锡东A2,\n', 'G123,德州东,11:43到,11:46开,检票口2,\n', 'G123,常州北,15:37到,15:39开,检票口A2,\n', 'G123,北京南,--:--到,10:14开,检票口16A、16B,\n', 'G123,徐州东,13:38到,13:40开,检票口东广场进站7A7B检票,\n', 'G123,曲阜东,12:59到,13:01开,检票口候车室检票口,\n', 'G123,上海虹桥,16:26到,--:--开,无检票口信息,\n'}
# {'G112,上海虹桥,--:--到,08:05开,检票口15AB,\n', 'G112,常州北,08:53到,08:55开,检票口B1,\n', 'G112,北京南,14:07到,--:--开,无检票口信息,\n', 'G112,济南西,12:12到,12:21开,检票口11B,\n', 'G112,廊坊,13:44到,13:46开,无检票口信息,\n', 'G112,徐州东,10:56到,11:07开,检票口东广场进站7A7B检票,\n', 'G112,苏州北,08:29到,08:31开,检票口1A1B,\n', 'G112,沧州西,13:07到,13:09开,检票口1,\n', 'G112,滁州,09:52到,09:54开,无检票口信息,\n', 'G112,南京南,09:26到,09:34开,检票口A8,\n'}
# {'G445,宜兴,16:02到,16:04开,无检票口信息,\n', 'G445,唐山,09:59到,10:01开,检票口A2,\n', 'G445,秦皇岛,--:--到,09:21开,检票口1,\n', 'G445,蚌埠南,14:26到,14:31开,检票口检票口2,\n', 'G445,杭州东,16:38到,--:--开,无检票口信息,\n', 'G445,天津西,10:51到,10:55开,检票口A9,\n', 'G445,溧阳,15:48到,15:50开,无检票口信息,\n', 'G445,溧水,15:31到,15:33开,无检票口信息,\n', 'G445,南京南,15:11到,15:14开,检票口A1,\n', 'G445,泰安,12:47到,12:50开,检票口检票口1 检票口2,\n', 'G445,天津,10:40到,10:43开,检票口6B,\n', 'G445,滨海西,10:21到,10:23开,检票口B2,\n', 'G445,济南西,12:14到,12:29开,检票口6A,\n', 'G445,德州东,11:48到,11:50开,检票口2,\n', 'G445,徐州东,13:42到,13:48开,检票口东广场进站7A7B检票,\n'}
# {'G37,桐庐,16:22到,16:25开,无检票口信息,\n', 'G37,杭州西,15:44到,15:51开,检票口2A,\n', 'G37,建德,16:39到,16:41开,无检票口信息,\n', 'G37,南京南,14:28到,14:34开,检票口A1,\n', 'G37,徐州东,13:17到,13:19开,检票口东广场进站7A7B检票,\n', 'G37,北京南,--:--到,10:56开,检票口14A、14B,\n', 'G37,富阳西,16:04到,16:07开,无检票口信息,\n', 'G37,千岛湖,16:54到,--:--开,无检票口信息,\n', 'G37,溧阳,15:01到,15:03开,无检票口信息,\n', 'G37,济南西,12:18到,12:20开,检票口5B,\n'}
# {'G9,北京南,--:--到,11:00开,检票口10A、10B,\n', 'G9,南京南,14:32到,14:34开,检票口A5,\n', 'G9,徐州东,13:21到,13:23开,检票口东广场进站7A7B检票,\n', 'G9,上海虹桥,15:37到,--:--开,无检票口信息,\n', 'G9,济南西,12:22到,12:24开,检票口7B,\n'}
# {'G1232,徐州东,11:15开,检票口东广场进站7A7B检票,泰安,\n', 'G1232,凤城东,19:08到,19:10开,无检票口信息,\n', 'G1232,本溪,18:36到,18:38开,检票口一层候车室A1检票口,\n', 'G1232,葫芦岛北,16:17到,16:19开,检票口候车室一楼,\n', 'G1232,13:45到,13:49开,检票口B14,滨海西,\n', 'G1232,锦州南,16:36到,16:37开,无检票口信息,\n', 'G1232,12:06到,12:08开,检票口检票口1 检票口2,济南西,\n', 'G1232,上海虹桥,--:--到,07:47开,检票口17B,\n', 'G1232,14:10到,14:13开,检票口A6,唐山,\n', 'G1232,12:26到,12:28开,检票口10B,沧州西,\n', 'G1232,蚌埠南,10:16到,10:21开,检票口检票口2,\n', 'G1232,沈阳,17:56到,17:59开,无检票口信息,\n', 'G1232,常州北,08:49到,08:51开,检票口A1,\n', 'G1232,沈阳南,18:10到,18:12开,无检票口信息,\n', 'G1232,15:31到,15:35开,无检票口信息,葫芦岛北,\n', 'G1232,15:14到,15:17开,检票口2,山海关,\n', 'G1232,苏州北,08:25到,08:27开,检票口1A,\n', 'G1232,13:13到,13:15开,检票口1,天津西,\n', 'G1232,滁州,09:46到,09:48开,无检票口信息,\n', 'G1232,14:34到,14:37开,检票口B4,秦皇岛,\n', 'G1232,山海关,15:31到,15:35开,无检票口信息,\n', 'G1232,秦皇岛,15:14到,15:17开,检票口2,\n', 'G1232,16:17到,16:19开,检票口候车室一楼,秦皇岛,15:14到,15:17开,检票口2,\n', 'G1232,南京南,09:22到,09:28开,检票口A7,\n', 'G1232,宿州东,10:44到,10:54开,检票口1,\n', 'G1232,丹东,19:27到,--:--开,无检票口信息,\n', 'G1232,昆山南,08:05到,08:14开,检票口2,\n', 'G1232,徐州东,11:13到,11:15开,检票口东广场进站7A7B检票,\n'}
# {'G114,徐州东,11:17到,11:19开,检票口东广场进站7A7B检票,\n', 'G114,南京南,09:42到,09:46开,检票口A6,\n', 'G114,济南西,12:30到,12:32开,检票口14B,\n', 'G114,北京南,14:12到,--:--开,无检票口信息,\n', 'G114,丹阳北,09:16到,09:18开,无检票口信息,\n', 'G114,无锡东,08:50到,08:52开,检票口无锡东A1,\n', 'G114,蚌埠南,10:29到,10:40开,无检票口信息,\n', 'G114,泰安,12:10到,12:12开,检票口检票口1 检票口2,\n', 'G114,上海虹桥,--:--到,08:15开,检票口13B,\n', 'G114,沧州西,13:17到,13:19开,检票口1,\n', 'G114,昆山南,08:32到,08:34开,检票口2,\n'}
# {'G181,15:48开,无检票口信息,溧水,15:58到,\n', 'G181,济南西,12:34到,12:39开,检票口5B,\n', 'G181,沧州西,11:36到,11:45开,检票口2,\n', 'G181,枣庄,13:36到,13:38开,检票口候车室检票口,\n', 'G181,苍南,20:30到,--:--开,无检票口信息,\n', 'G181,青田,19:26到,19:28开,无检票口信息,\n', 'G181,温州南,19:47到,19:52开,检票口第二候车室5号检票口,\n', 'G181,16:55开,无检票口信息,杭州东,17:08到,\n', 'G181,平阳,20:15到,20:18开,检票口2,\n', 'G181,瑞安,20:03到,20:05开,无检票口信息,\n', 'G181,缙云西,18:49到,18:51开,无检票口信息,\n', 'G181,16:36开,无检票口信息,德清,16:53到,\n', 'G181,17:53开,检票口1号检票口,金华南,18:10到,\n', 'G181,17:37开,无检票口信息,义乌,17:51到,\n', 'G181,丽水,19:04到,19:06开,检票口2层候车室,\n', 'G181,江宁,15:33到,15:38开,无检票口信息,\n', 'G181,南京南,15:18到,15:24开,检票口A2,\n', 'G181,徐州东,13:56到,13:58开,检票口东广场进站7A7B检票,\n', 'G181,17:11开,检票口8A,诸暨,17:35到,\n', 'G181,江宁,15:38开,句容西,15:46到,\n', 'G181,泰安,12:56到,12:58开,检票口检票口1 检票口2,\n', 'G181,武义北,18:23到,18:25开,无检票口信息,\n', 'G181,16:00开,无检票口信息,长兴,16:30到,\n', 'G181,18:12开,无检票口信息,武义北,18:23到,\n', 'G181,18:25开,无检票口信息,武义北,18:23到,18:25开,无检票口信息,\n', 'G181,蚌埠南,14:35到,14:37开,检票口检票口2,\n', 'G181,北京南,--:--到,10:42开,检票口15A、15B,\n', 'G181,永康南,18:37到,18:39开,检票口一号,\n'}
# {'G2586,沧州西,13:25到,13:27开,检票口1,\n', 'G2586,东台,09:16到,09:18开,检票口二层检票口,\n', 'G2586,海安,09:01到,09:03开,检票口二楼检票口,\n', 'G2586,曲阜东,12:00到,12:02开,检票口候车室检票口,\n', 'G2586,如皋南,08:49到,08:51开,检票口一楼检票口,\n', 'G2586,宿迁,10:40到,10:42开,检票口2,\n', 'G2586,济南西,12:34到,12:40开,检票口12B,\n', 'G2586,徐州东,11:16到,11:23开,检票口东广场进站7A7B检票,\n', 'G2586,天津南,13:50到,13:56开,检票口1,\n', 'G2586,北京南,14:31到,--:--开,无检票口信息,\n', 'G2586,盐城,09:36到,09:38开,检票口1A2A,\n', 'G2586,南通,--:--到,08:30开,检票口一楼,\n', 'G2586,淮安东,10:10到,10:12开,检票口2A3A,\n'}
# {'G2556,泾县,08:38到,08:40开,无检票口信息,\n', 'G2556,曲阜东,12:04到,12:06开,检票口候车室检票口,\n', 'G2556,绩溪北,08:16到,08:18开,检票口2,\n', 'G2556,水家湖,10:16到,10:19开,无检票口信息,\n', 'G2556,沧州西,13:32到,13:40开,检票口1,\n', 'G2556,徐州东,11:21到,11:27开,检票口东广场进站7A7B检票,\n', 'G2556,铜陵北,08:57到,08:59开,无检票口信息,\n', 'G2556,歙县北,08:03到,08:05开,无检票口信息,\n', 'G2556,济南西,12:38到,12:44开,检票口10B,\n', 'G2556,北京南,14:35到,--:--开,无检票口信息,\n', 'G2556,合肥南,09:36到,09:42开,检票口21A,\n', 'G2556,蚌埠南,10:40到,10:45开,检票口检票口1,\n', 'G2556,黄山北,--:--到,07:55开,检票口2层检票,\n'}
# {'G1224,余姚北,07:35到,07:38开,检票口A1,\n', 'G1224,南京南,10:00到,10:06开,检票口B9,\n', 'G1224,14:25开,检票口A16,唐山,15:03到,\n', 'G1224,13:26开,检票口1,天津西,14:22到,\n', 'G1224,10:50开,检票口检票口2,徐州东,11:26到,\n', 'G1224,天津西,14:22到,14:25开,检票口A16,\n', 'G1224,绍兴北,08:00到,08:02开,检票口1B2B,\n', 'G1224,15:09开,检票口B4,秦皇岛,15:47到,\n', 'G1224,锦州南,17:10到,17:12开,无检票口信息,\n', 'G1224,秦皇岛,15:47到,15:53开,检票口2,\n', 'G1224,杭州东,08:20到,08:29开,检票口5B,\n', 'G1224,唐山,15:03到,15:09开,检票口B4,\n', 'G1224,11:58开,无检票口信息,济南西,12:42到,\n', 'G1224,德州东,13:12到,13:26开,检票口1,\n', 'G1224,山海关,16:07到,16:09开,无检票口信息,\n', 'G1224,宜兴,09:11到,09:13开,无检票口信息,\n', 'G1224,15:53开,检票口2,山海关,16:07到,\n', 'G1224,11:31开,检票口东广场进站7A7B检票,滕州东,11:56到,\n', 'G1224,济南西,12:42到,12:48开,检票口11A,\n', 'G1224,绥中北,16:33到,16:35开,无检票口信息,\n', 'G1224,湖州,08:51到,08:54开,检票口二层检票口,\n', 'G1224,宁波,--:--到,07:15开,检票口9B,\n', 'G1224,句容西,09:46到,09:48开,无检票口信息,\n', 'G1224,16:09开,无检票口信息,济南西,12:42到,12:48开,检票口11A,\n', 'G1224,12:48开,检票口11A,德州东,13:12到,\n', 'G1224,溧水,09:35到,09:37开,无检票口信息,\n', 'G1224,沈阳北,18:29到,--:--开,无检票口信息,\n', 'G1224,南京南,10:06开,蚌埠南,10:48到,\n'}
# {'G1209,镇江南,16:23到,16:25开,无检票口信息,\n', 'G1209,蚌埠南,14:52到,14:58开,检票口检票口2,\n', 'G1209,无锡东,17:01到,17:10开,检票口无锡东A2,\n', 'G1209,徐州东,14:12到,14:14开,检票口东广场进站7A7B检票,\n', 'G1209,济南西,--:--到,12:44开,检票口4B,\n', 'G1209,上海虹桥,17:47到,--:--开,无检票口信息,\n', 'G1209,南京南,16:00到,16:04开,检票口A3,\n', 'G1209,常州北,16:43到,16:45开,检票口A2,\n', 'G1209,苏州北,17:20到,17:22开,检票口2B,\n', 'G1209,滕州东,13:45到,13:47开,检票口检票口,\n', 'G1209,定远,15:14到,15:30开,无检票口信息,\n', 'G1209,泰安,13:01到,13:14开,检票口检票口1 检票口2,\n'}
# {'G174,宁波,07:35到,07:41开,检票口11A,\n', 'G174,台州西,--:--到,06:41开,无检票口信息,\n', 'G174,湖州,09:10到,09:12开,检票口二层检票口,\n', 'G174,北京南,14:40到,--:--开,无检票口信息,\n', 'G174,枣庄,11:53到,11:55开,检票口候车室检票口,\n', 'G174,绍兴东,08:10到,08:12开,检票口1,\n', 'G174,定远,10:40到,10:42开,无检票口信息,\n', 'G174,宜兴,09:29到,09:31开,无检票口信息,\n', 'G174,德州东,13:16到,13:22开,检票口2,\n', 'G174,南京南,10:06到,10:10开,检票口A7,\n', 'G174,徐州东,11:30到,11:35开,检票口东广场进站7A7B检票,\n', 'G174,杭州东,08:45到,08:49开,检票口7A,\n', 'G174,济南西,12:46到,12:52开,检票口14B,\n', 'G174,绍兴北,08:24到,08:26开,检票口1B2B,\n'}
# {'G2624,秦皇岛,16:05到,16:09开,检票口2,\n', 'G2624,辽中,18:20到,18:22开,无检票口信息,\n', 'G2624,16:27开,无检票口信息,葫芦岛北,17:10到,\n', 'G2624,16:09开,检票口2,山海关,16:23到,\n', 'G2624,锦州南,17:28到,17:29开,无检票口信息,\n', 'G2624,13:04开,检票口12A,德州东,13:28到,\n', 'G2624,瓦屋山,09:37到,09:39开,无检票口信息,\n', 'G2624,溧水,09:49到,09:54开,无检票口信息,\n', 'G2624,南京南,10:11到,10:14开,检票口B10,\n', 'G2624,滁州,10:32到,10:34开,无检票口信息,\n', 'G2624,宜兴,09:18到,09:20开,无检票口信息,\n', 'G2624,13:33开,检票口1,天津西,14:26到,\n', 'G2624,14:57开,无检票口信息,唐山,15:14到,\n', 'G2624,杭州西,--:--到,08:32开,检票口10A,\n', 'G2624,15:16开,检票口B5,滦河,15:34到,\n', 'G2624,17:11开,检票口候车室一楼,滦河,15:34到,15:40开,无检票口信息,\n', 'G2624,沈阳北,18:52到,18:58开,无检票口信息,\n', 'G2624,枣庄,11:59开,济南西,12:50到,\n', 'G2624,葫芦岛北,17:10到,17:11开,检票口候车室一楼,\n', 'G2624,长春西,20:10到,--:--开,无检票口信息,\n', 'G2624,滦河,15:34到,15:40开,无检票口信息,\n', 'G2624,14:30开,检票口B17,滨海北,14:55到,\n', 'G2624,铁岭西,19:16到,19:18开,无检票口信息,\n', 'G2624,徐州东,11:34到,11:39开,检票口东广场进站7A7B检票,\n', 'G2624,山海关,16:23到,16:27开,无检票口信息,\n', 'G2624,枣庄,11:57到,11:59开,无检票口信息,\n', 'G2624,15:40开,无检票口信息,秦皇岛,16:05到,\n', 'G2624,德清,08:46到,08:52开,无检票口信息,\n'}
# {'G125,廊坊,11:09到,11:18开,无检票口信息,\n', 'G125,蚌埠南,14:39到,14:41开,检票口检票口2,\n', 'G125,南京南,15:22到,15:26开,检票口A5,\n', 'G125,无锡东,16:19到,16:21开,检票口无锡东A2,\n', 'G125,德州东,12:23到,12:26开,检票口2,\n', 'G125,常州北,15:58到,16:03开,检票口A2,\n', 'G125,北京南,--:--到,10:46开,检票口13A、13B,\n', 'G125,天津南,11:37到,11:39开,检票口2,\n', 'G125,济南西,12:51到,12:54开,检票口5B,\n', 'G125,枣庄,13:44到,13:47开,检票口候车室检票口,\n', 'G125,上海虹桥,16:50到,--:--开,无检票口信息,\n'}
# {'G127,济南西,12:55到,12:58开,检票口6B,\n', 'G127,宿州东,14:24到,14:26开,检票口1,\n', 'G127,南京南,15:37到,15:39开,检票口A4,\n', 'G127,滁州,15:14到,15:19开,无检票口信息,\n', 'G127,上海虹桥,17:08到,--:--开,无检票口信息,\n', 'G127,德州东,12:28到,12:31开,检票口2,\n', 'G127,天津南,11:41到,11:43开,检票口2,\n', 'G127,无锡东,16:29到,16:31开,检票口无锡东A2,\n', 'G127,北京南,--:--到,11:05开,检票口16A、16B,\n', 'G127,枣庄,13:48到,13:51开,检票口候车室检票口,\n', 'G127,丹阳北,16:04到,16:06开,无检票口信息,\n', 'G127,昆山南,16:48到,16:50开,检票口1,\n'}
# {'G10,济南西,12:58到,13:00开,检票口11B,\n', 'G10,南京南,10:59到,11:01开,检票口A6,\n', 'G10,上海虹桥,--:--到,10:00开,检票口1AB,\n', 'G10,北京南,14:26到,--:--开,无检票口信息,\n'}
# {'G129,蚌埠南,15:09到,15:15开,检票口检票口1,\n', 'G129,常州北,16:38到,16:40开,检票口A2,\n', 'G129,无锡东,16:57到,16:59开,检票口无锡东A2,\n', 'G129,曲阜东,13:39到,13:41开,检票口候车室检票口,\n', 'G129,德州东,12:39到,12:41开,检票口2,\n', 'G129,天津南,11:52到,11:54开,检票口2,\n', 'G129,枣庄,14:04到,14:06开,无检票口信息,\n', 'G129,镇江南,16:18到,16:20开,无检票口信息,\n', 'G129,北京南,--:--到,11:18开,检票口8A、8B,\n', 'G129,济南西,13:05到,13:07开,检票口7B,\n', 'G129,苏州北,17:09到,17:15开,检票口2B,\n', 'G129,上海虹桥,17:38到,--:--开,无检票口信息,\n', 'G129,徐州东,14:24到,14:31开,检票口东广场进站7A7B检票,\n', 'G129,南京南,15:56到,15:59开,检票口A5,\n'}
# {'G131,常州北,16:33到,16:35开,检票口A2,\n', 'G131,镇江南,16:13到,16:15开,无检票口信息,\n', 'G131,北京南,--:--到,11:27开,检票口17A、17B,\n', 'G131,德州东,12:43到,12:45开,检票口2,\n', 'G131,徐州东,14:37到,14:39开,检票口东广场进站7A7B检票,\n', 'G131,济南西,13:09到,13:12开,检票口5B,\n', 'G131,苏州北,16:57到,16:59开,检票口2B,\n', 'G131,曲阜东,13:44到,13:47开,无检票口信息,\n', 'G131,上海虹桥,17:22到,--:--开,无检票口信息,\n', 'G131,南京南,15:52到,15:54开,检票口B1,\n', 'G131,枣庄,14:10到,14:19开,无检票口信息,\n'}
# {'G176,曲阜东,12:28到,12:37开,检票口候车室检票口,\n', 'G176,德清,09:10到,09:12开,无检票口信息,\n', 'G176,南京南,10:21到,10:26开,检票口A9,\n', 'G176,北京南,14:51到,--:--开,无检票口信息,\n', 'G176,杭州东,08:51到,08:57开,检票口4A,\n', 'G176,长兴,09:29到,09:31开,无检票口信息,\n', 'G176,徐州东,11:48到,11:50开,检票口东广场进站7A7B检票,\n', 'G176,宿州东,11:28到,11:30开,检票口1,\n', 'G176,诸暨,--:--到,08:27开,无检票口信息,\n', 'G176,瓦屋山,09:56到,09:58开,无检票口信息,\n', 'G176,德州东,13:36到,13:38开,检票口2,\n', 'G176,济南西,13:09到,13:12开,检票口10B,\n'}
# {'G1273,上饶,18:50到,18:52开,检票口一层5B号检票口,\n', 'G1273,绥中北,09:38到,09:41开,无检票口信息,\n', 'G1273,18:03开,检票口2层检票,婺源,18:24到,\n', 'G1273,锦州南,08:53到,08:55开,无检票口信息,\n', 'G1273,18:26开,无检票口信息,上饶,18:50到,\n', 'G1273,13:17开,检票口6B,曲阜东,13:49到,\n', 'G1273,葫芦岛北,09:13到,09:16开,无检票口信息,\n', 'G1273,武夷山北,19:16到,19:23开,无检票口信息,\n', 'G1273,沈阳,07:20到,07:31开,无检票口信息,\n', 'G1273,12:30开,检票口2,济南西,13:15到,\n', 'G1273,黄山北,17:58到,18:03开,检票口2层检票,\n', 'G1273,唐山,11:16开,天津西,11:51到,\n', 'G1273,13:51开,无检票口信息,滕州东,14:07到,\n', 'G1273,15:04开,无检票口信息,淮南东,15:38到,\n', 'G1273,福州,20:55到,20:59开,检票口8检票口,\n', 'G1273,19:23开,无检票口信息,南平市,19:35到,\n', 'G1273,20:06开,无检票口信息,黄山北,17:58到,18:03开,检票口2层检票,\n', 'G1273,山海关,10:06到,10:11开,无检票口信息,\n', 'G1273,婺源,18:24到,18:26开,无检票口信息,\n', 'G1273,18:52开,检票口一层5B号检票口,武夷山北,19:16到,\n', 'G1273,17:22开,无检票口信息,黄山北,17:58到,\n', 'G1273,17:08开,无检票口信息,南陵,17:20到,\n', 'G1273,延平,20:04到,20:06开,无检票口信息,\n', 'G1273,15:40开,无检票口信息,合肥南,16:19到,\n', 'G1273,秦皇岛,10:26到,10:28开,检票口1,\n', 'G1273,16:46开,无检票口信息,铜陵北,17:06到,\n', 'G1273,南平市,19:35到,19:37开,无检票口信息,\n', 'G1273,闽清北,20:27到,20:34开,无检票口信息,\n', 'G1273,唐山,11:13到,11:16开,检票口A3,\n', 'G1273,14:14开,无检票口信息,徐州东,14:41到,\n', 'G1273,滦河,10:53到,10:55开,无检票口信息,\n', 'G1273,11:56开,无检票口信息,沧州西,12:28到,\n', 'G1273,16:23开,检票口16B,合肥南,16:23开,巢湖东,16:44到,\n', 'G1273,19:37开,无检票口信息,延平,20:04到,\n', 'G1273,福州南,21:14到,--:--开,无检票口信息,\n', 'G1273,14:43开,检票口东广场进站7A7B检票,宿州东,15:02到,\n', 'G1273,沈阳南,--:--到,07:09开,无检票口信息,\n'}
# {'G1236,检票口B4,秦皇岛,15:59到,16:02开,\n', 'G1236,无检票口信息,沈阳北,18:35到,18:38开,\n', 'G1236,徐州东,12:01到,12:07开,检票口东广场进站7A7B检票,\n', 'G1236,检票口B15,唐山,15:19到,15:22开,\n', 'G1236,枣庄,济南西,13:19到,13:22开,\n', 'G1236,无检票口信息,葫芦岛北,17:02到,17:03开,\n', 'G1236,秦皇岛,15:59到,16:02开,无检票口信息,\n', 'G1236,唐山,15:19到,15:22开,检票口B4,\n', 'G1236,长春西,19:59到,20:01开,无检票口信息,\n', 'G1236,检票口13A,天津西,14:33到,14:42开,\n', 'G1236,无检票口信息,四平东,19:22到,19:33开,\n', 'G1236,四平东,19:22到,19:33开,无检票口信息,\n', 'G1236,无检票口信息,长春西,19:59到,20:01开,\n', 'G1236,枣庄,12:25到,12:29开,无检票口信息,\n', 'G1236,葫芦岛北,17:02到,17:03开,无检票口信息,\n', 'G1236,苏州北,09:27到,09:29开,检票口1A,\n', 'G1236,南京南,10:32到,10:34开,检票口A10,\n', 'G1236,长春,20:12到,20:15开,无检票口信息,\n', 'G1236,山海关,16:16到,16:19开,无检票口信息,\n', 'G1236,丹阳北,10:05到,10:07开,无检票口信息,\n', 'G1236,宿州东,11:40到,11:42开,无检票口信息,\n', 'G1236,沈阳北,18:35到,18:38开,无检票口信息,\n', 'G1236,滁州,10:52到,10:54开,无检票口信息,\n', 'G1236,吉林,20:55到,--:--开,无检票口信息,\n', 'G1236,无锡东,09:39到,09:41开,检票口无锡东A1,\n', 'G1236,无检票口信息,山海关,16:16到,16:19开,\n', 'G1236,上海虹桥,--:--到,09:04开,检票口14B,\n', 'G1236,无检票口信息,唐山,15:19到,15:22开,检票口B4,\n'}
# {'G1223,检票口二层检票口,杭州东,17:37到,17:41开,\n', 'G1223,唐山,11:20到,11:22开,检票口B2,\n', 'G1223,检票口1,南京南,16:17到,16:22开,\n', 'G1223,检票口B2,宜兴,16:56到,16:58开,\n', 'G1223,台安,08:34到,08:36开,检票口二楼检票口,\n', 'G1223,沧州西,12:33到,12:35开,检票口2,\n', 'G1223,沧州西,济南西,13:20到,13:23开,\n', 'G1223,徐州东,14:50到,14:52开,检票口东广场进站7A7B检票,\n', 'G1223,余姚北,18:15到,18:17开,检票口B2,\n', 'G1223,盘锦北,08:57到,08:59开,无检票口信息,\n', 'G1223,宜兴,16:56到,16:58开,无检票口信息,\n', 'G1223,湖州,17:14到,17:16开,检票口二层检票口,\n', 'G1223,杭州东,17:37到,17:41开,检票口10B,\n', 'G1223,检票口候车室检票口,徐州东,14:50到,14:52开,\n', 'G1223,检票口候车室检票口,枣庄,14:30到,14:32开,\n', 'G1223,检票口东广场进站7A7B检票,宿州东,15:11到,15:16开,\n', 'G1223,枣庄,14:30到,14:32开,检票口候车室检票口,\n', 'G1223,锦州南,09:24到,09:26开,无检票口信息,\n', 'G1223,宿州东,15:11到,15:16开,检票口1,\n', 'G1223,秦皇岛,10:39到,10:42开,检票口2,\n', 'G1223,无检票口信息,湖州,17:14到,17:16开,\n', 'G1223,南京南,16:17到,16:22开,检票口B2,\n', 'G1223,检票口10B,枣庄,14:30到,14:32开,检票口候车室检票口,\n', 'G1223,天津西,11:57到,12:01开,检票口B10,\n', 'G1223,宁波,18:37到,--:--开,无检票口信息,\n', 'G1223,沈阳北,--:--到,07:53开,无检票口信息,\n', 'G1223,检票口4A,曲阜东,13:55到,14:06开,\n', 'G1223,山海关,10:22到,10:25开,无检票口信息,\n'}
# {'G378,定远,11:24到,11:29开,无检票口信息,\n', 'G378,石家庄,15:19到,--:--开,无检票口信息,\n', 'G378,滁州,11:05到,11:07开,无检票口信息,\n', 'G378,徐州东,12:24到,12:26开,检票口东广场进站7A7B检票,\n', 'G378,衡水北,14:31到,14:33开,无检票口信息,\n', 'G378,常州北,10:11到,10:13开,检票口A1,\n', 'G378,辛集南,14:49到,14:51开,无检票口信息,\n', 'G378,济南西,13:30到,13:35开,检票口14B,\n', 'G378,南京南,10:45到,10:47开,检票口A10,\n', 'G378,上海虹桥,--:--到,09:14开,检票口17B,\n', 'G378,蚌埠南,11:45到,11:47开,无检票口信息,\n', 'G378,昆山南,09:31到,09:36开,检票口2,\n', 'G378,苏州北,09:47到,09:49开,检票口1A,\n'}
# {'G11,天津南,12:31到,12:33开,检票口2,\n', 'G11,北京南,--:--到,12:00开,检票口10A、10B,\n', 'G11,济南西,13:33到,13:35开,检票口6B,\n', 'G11,上海虹桥,16:38到,--:--开,无检票口信息,\n', 'G11,南京南,15:33到,15:35开,检票口B1,\n'}
# {'G116,天津南,14:39到,14:41开,检票口1,\n', 'G116,苏州北,09:51到,09:53开,检票口1A1B,\n', 'G116,南京南,10:49到,10:53开,检票口A9,\n', 'G116,常州北,10:16到,10:18开,检票口B1,\n', 'G116,滁州,11:11到,11:21开,无检票口信息,\n', 'G116,蚌埠南,11:49到,11:51开,检票口检票口1,\n', 'G116,徐州东,12:28到,12:30开,检票口东广场进站7A7B检票,\n', 'G116,廊坊,14:59到,15:01开,无检票口信息,\n', 'G116,北京南,15:22到,--:--开,无检票口信息,\n', 'G116,上海虹桥,--:--到,09:26开,检票口15AB,\n', 'G116,济南西,13:34到,13:36开,检票口11A,\n'}
# {'G178,溧水,10:45到,10:47开,无检票口信息,\n', 'G178,衢州,08:14到,08:16开,检票口检票口1,\n', 'G178,宜兴,10:21到,10:23开,无检票口信息,\n', 'G178,南京南,11:03到,11:12开,检票口A10,\n', 'G178,诸暨,09:18到,09:20开,无检票口信息,\n', 'G178,廊坊,15:19到,15:22开,无检票口信息,\n', 'G178,天津南,14:52到,15:01开,检票口1,\n', 'G178,江山,--:--到,08:03开,无检票口信息,\n', 'G178,北京南,15:43到,--:--开,无检票口信息,\n', 'G178,蚌埠南,11:53到,11:55开,无检票口信息,\n', 'G178,金华,08:44到,08:46开,检票口10,\n', 'G178,沧州西,14:28到,14:30开,检票口1,\n', 'G178,杭州东,09:44到,09:48开,检票口4A,\n', 'G178,徐州东,12:32到,12:34开,检票口东广场进站7A7B检票,\n', 'G178,济南西,13:38到,13:42开,检票口12B,\n', 'G178,龙游,08:27到,08:29开,检票口二层检票口,\n', 'G178,义乌,09:02到,09:04开,检票口2号检票口,\n'}
# {'G133,枣庄,14:34到,14:36开,检票口候车室检票口,\n', 'G133,无锡东,17:20到,17:22开,检票口无锡东A2,\n', 'G133,德州东,13:10到,13:15开,检票口2,\n', 'G133,济南西,13:39到,13:44开,检票口7B,\n', 'G133,镇江南,16:35到,16:37开,无检票口信息,\n', 'G133,徐州东,14:54到,14:57开,检票口东广场进站7A7B检票,\n', 'G133,上海,18:02到,--:--开,无检票口信息,\n', 'G133,沧州西,12:41到,12:43开,检票口2,\n', 'G133,常州北,16:54到,17:04开,检票口A2,\n', 'G133,南京南,16:13到,16:16开,检票口A4,\n', 'G133,苏州北,17:33到,17:35开,检票口2B,\n', 'G133,北京南,--:--到,11:49开,检票口11A、11B,\n'}
# {'G1274,沧州西,14:35到,14:44开,检票口1,\n', 'G1274,铜陵北,合肥南,11:13到,11:15开,\n', 'G1274,福州南,--:--到,06:57开,检票口16/17A,\n', 'G1274,唐山,15:56到,15:58开,检票口B4,\n', 'G1274,延平,07:53到,07:55开,无检票口信息,\n', 'G1274,无检票口信息,沈阳,19:05到,19:13开,\n', 'G1274,沈阳南,19:24到,--:--开,无检票口信息,\n', 'G1274,天津西,15:16到,15:19开,无检票口信息,\n', 'G1274,锦州南,17:45到,17:47开,无检票口信息,\n', 'G1274,无检票口信息,徐州东,12:37到,12:39开,检票口东广场进站7A7B检票,\n', 'G1274,婺源,09:18到,09:20开,无检票口信息,\n', 'G1274,秦皇岛,16:35到,16:38开,无检票口信息,\n', 'G1274,检票口18A,徐州东,12:37到,12:39开,\n', 'G1274,无检票口信息,唐山,15:56到,15:58开,\n', 'G1274,上饶,08:53到,08:55开,检票口一层6B号检票口,\n', 'G1274,铜陵北,10:34到,10:36开,无检票口信息,\n', 'G1274,福州,07:11到,07:19开,检票口2检票口,\n', 'G1274,无检票口信息,锦州南,17:45到,17:47开,\n', 'G1274,南平市,08:21到,08:23开,无检票口信息,\n', 'G1274,检票口B4,秦皇岛,16:35到,16:38开,\n', 'G1274,绩溪北,10:00到,10:02开,检票口2,\n', 'G1274,黄山北,09:44到,09:46开,检票口2层检票,\n', 'G1274,检票口东广场进站7A7B检票,济南西,13:43到,13:48开,\n', 'G1274,检票口14B,沧州西,14:35到,14:44开,\n', 'G1274,徐州东,12:37到,12:39开,检票口东广场进站7A7B检票,\n', 'G1274,沈阳,19:05到,19:13开,无检票口信息,\n', 'G1274,济南西,13:43到,13:48开,检票口14B,\n', 'G1274,检票口1,天津西,15:16到,15:19开,\n'}
# {'G303,无检票口信息,延平,20:18到,20:20开,\n', 'G303,婺源,18:51到,18:53开,无检票口信息,\n', 'G303,蚌埠南,15:46到,15:54开,检票口二楼检票,\n', 'G303,旌德,18:04到,18:06开,无检票口信息,\n', 'G303,检票口一层5A号检票口,南平市,19:48到,19:52开,\n', 'G303,济南西,13:46到,13:48开,检票口5B,\n', 'G303,枣庄,14:45到,14:48开,检票口候车室检票口,\n', 'G303,检票口17A,铜陵北,17:36到,17:38开,\n', 'G303,水家湖,合肥南,16:53到,16:58开,\n', 'G303,无检票口信息,黄山北,18:27到,18:30开,\n', 'G303,德州东,13:20到,13:22开,检票口2,\n', 'G303,北京南,--:--到,11:53开,检票口16A、16B,\n', 'G303,福州,21:03到,--:--开,无检票口信息,\n', 'G303,南平市,19:48到,19:52开,无检票口信息,\n', 'G303,延平,20:18到,20:20开,无检票口信息,\n', 'G303,闽清北,20:40到,20:42开,无检票口信息,\n', 'G303,沧州西,12:48到,12:53开,检票口2,\n', 'G303,检票口2层检票,婺源,18:51到,18:53开,\n', 'G303,无检票口信息,铜陵北,17:36到,17:38开,无检票口信息,\n', 'G303,无检票口信息,上饶,19:17到,19:19开,\n', 'G303,水家湖,16:14到,16:17开,无检票口信息,\n', 'G303,铜陵北,17:36到,17:38开,无检票口信息,\n', 'G303,无检票口信息,闽清北,20:40到,20:42开,\n', 'G303,黄山北,18:27到,18:30开,检票口2层检票,\n', 'G303,无检票口信息,旌德,18:04到,18:06开,\n', 'G303,上饶,19:17到,19:19开,检票口一层5A号检票口,\n', 'G303,滕州东,14:31到,14:33开,检票口检票口,\n', 'G303,宿州东,15:20到,15:23开,检票口1,\n'}
# {'G1204,15:24开,检票口B13,滨海北,15:50到,\n', 'G1204,19:25开,无检票口信息,开原西,19:53到,\n', 'G1204,盘锦北,18:25到,18:27开,无检票口信息,\n', 'G1204,17:09开,无检票口信息,盘锦北,18:25到,\n', 'G1204,秦皇岛,16:47到,16:51开,无检票口信息,\n', 'G1204,常州北,10:20到,10:22开,检票口A1,\n', 'G1204,上海虹桥,--:--到,09:33开,检票口2AB,\n', 'G1204,开原西,19:53到,19:55开,无检票口信息,\n', 'G1204,镇江南,10:40到,10:45开,无检票口信息,\n', 'G1204,徐州东,12:41到,12:44开,检票口东广场进站7A7B检票,\n', 'G1204,沈阳北,19:22到,19:25开,无检票口信息,\n', 'G1204,济南西,13:53开,德州东,14:17到,\n', 'G1204,14:26开,检票口1,天津西,15:21到,\n', 'G1204,19:55开,无检票口信息,唐山,16:08到,16:10开,检票口B5,\n', 'G1204,山海关,17:05到,17:09开,无检票口信息,\n', 'G1204,蚌埠南,11:58到,12:05开,无检票口信息,\n', 'G1204,苏州北,09:56到,09:58开,检票口1A1B,\n', 'G1204,南京南,11:04到,11:06开,检票口B8,\n', 'G1204,长春西,20:45到,20:48开,无检票口信息,\n', 'G1204,16:10开,检票口B5,秦皇岛,16:47到,\n', 'G1204,昌图西,20:06到,20:08开,无检票口信息,\n', 'G1204,15:52开,无检票口信息,唐山,16:08到,\n', 'G1204,滁州,11:24到,11:30开,无检票口信息,\n', 'G1204,济南西,13:48到,13:53开,检票口13A,\n', 'G1204,18:27开,无检票口信息,沈阳北,19:22到,\n', 'G1204,唐山,16:08到,16:10开,检票口B5,\n', 'G1204,哈尔滨西,21:45到,--:--开,无检票口信息,\n', 'G1204,16:51开,无检票口信息,山海关,17:05到,\n'}
# {'G325,枣庄,14:55到,15:00开,无检票口信息,\n', 'G325,南平市,20:30到,20:32开,无检票口信息,\n', 'G325,18:31开,无检票口信息,歙县北,18:57到,\n', 'G325,泉州南,22:50到,22:52开,无检票口信息,\n', 'G325,18:11开,无检票口信息,泾县,18:28到,\n', 'G325,北京南,--:--到,12:04开,检票口15A、15B,\n', 'G325,婺源,19:33到,19:35开,无检票口信息,\n', 'G325,蚌埠南,16:06到,16:08开,无检票口信息,\n', 'G325,曲阜东,14:25到,14:32开,无检票口信息,\n', 'G325,上饶,19:59到,20:01开,检票口一层5A5B号检票口,\n', 'G325,17:42开,无检票口信息,无为,17:55到,\n', 'G325,建瓯西,20:48到,20:50开,无检票口信息,\n', 'G325,福州南,21:57到,21:59开,检票口22/23B,\n', 'G325,19:12开,检票口2层检票,婺源,19:33到,\n', 'G325,18:59开,无检票口信息,黄山北,19:08到,\n', 'G325,淮南东,16:24到,16:26开,无检票口信息,\n', 'G325,淮南东,16:26开,合肥北城,16:46到,\n', 'G325,19:35开,无检票口信息,婺源,19:33到,19:35开,无检票口信息,\n', 'G325,莆田,22:24到,22:26开,检票口二层6A / 7A 检票口,\n', 'G325,福州,21:39到,21:43开,检票口11检票口,\n', 'G325,17:19开,无检票口信息,巢湖东,17:40到,\n', 'G325,徐州东,15:19到,15:29开,检票口东广场进站7A7B检票,\n', 'G325,德州东,13:24到,13:26开,检票口2,\n', 'G325,济南西,13:50到,13:53开,检票口6B,\n', 'G325,天津南,12:38到,12:40开,检票口2,\n', 'G325,厦门北,23:09到,--:--开,无检票口信息,\n', 'G325,16:51开,无检票口信息,合肥南,17:15到,\n', 'G325,17:57开,无检票口信息,铜陵北,18:09到,\n'}
# {'G2573,淮安东,16:29到,16:32开,检票口4B5B,\n', 'G2573,泰州,17:42到,--:--开,无检票口信息,\n', 'G2573,济南西,13:54到,13:59开,检票口7B,\n', 'G2573,天津南,12:42到,12:44开,检票口2,\n', 'G2573,枣庄,14:49到,14:52开,检票口候车室检票口,\n', 'G2573,宿迁,15:53到,15:55开,检票口2,\n', 'G2573,德州东,13:28到,13:30开,检票口2,\n', 'G2573,徐州东,15:10到,15:13开,检票口东广场进站7A7B检票,\n', 'G2573,睢宁,15:39到,15:41开,无检票口信息,\n', 'G2573,北京南,--:--到,12:08开,检票口14A、14B,\n', 'G2573,高邮北,16:54到,16:56开,无检票口信息,\n', 'G2573,江都,17:21到,17:23开,无检票口信息,\n', 'G2573,泗阳,16:10到,16:12开,无检票口信息,\n'}
# {'G42,合肥南,--:--到,11:41开,检票口22A,\n', 'G42,北京南,15:26到,--:--开,无检票口信息,\n', 'G42,济南西,13:57到,14:00开,检票口12B,\n', 'G42,蚌埠南,12:31到,12:33开,检票口检票口1,\n'}
# {'G135,常州北,17:24到,17:26开,检票口A2,\n', 'G135,南京南,16:49到,16:52开,检票口A4,\n', 'G135,曲阜东,14:42到,14:44开,检票口候车室检票口,\n', 'G135,苏州北,17:56到,17:58开,检票口2B,\n', 'G135,上海虹桥,18:21到,--:--开,无检票口信息,\n', 'G135,北京南,--:--到,12:12开,检票口17A、17B,\n', 'G135,枣庄,15:07到,15:16开,检票口候车室检票口,\n', 'G135,沧州西,13:10到,13:12开,检票口2,\n', 'G135,无锡东,17:43到,17:45开,检票口无锡东A2,\n', 'G135,天津南,12:46到,12:48开,检票口2,\n', 'G135,济南西,13:59到,14:03开,检票口4B,\n', 'G135,泰安,14:20到,14:22开,检票口检票口1 检票口2,\n', 'G135,徐州东,15:35到,15:37开,检票口东广场进站7A7B检票,\n'}
# {'G12,上海虹桥,--:--到,11:00开,检票口1AB,\n', 'G12,南京南,12:00到,12:02开,检票口A6,\n', 'G12,北京南,15:31到,--:--开,无检票口信息,\n', 'G12,济南西,14:02到,14:04开,检票口10B,\n'}
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# c:\Users\z'z'x\Desktop\车次处理\appnium版,以济南西站为例.ipynb 单元格 6 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=17'>18</a> # 获取所有济南西站的车次信息
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=18'>19</a> jnzlist = stationFrame[stationFrame["停站"] == targetSt]["车次"].to_list()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=19'>20</a> TrainStationList(driver, action, jnzlist, "jinanxitest2.txt")
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=21'>22</a> time.sleep(3)
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=22'>23</a> # driver.close()
#
# c:\Users\z'z'x\Desktop\车次处理\appnium版,以济南西站为例.ipynb 单元格 6 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=96'>97</a> beforeSwipe = driver.page_source
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=98'>99</a> for btn in searchbtns:  # 当前页面上所有“查询”按钮，目前除了全部重复点一遍没有好办法
#     <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=99'>100</a>     # if btn.id in btnClicked:
#     <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=100'>101</a>     #     continue
# --> <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=101'>102</a>     action.tap(btn).perform()  # 点选所有按钮进行查找
#     <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=102'>103</a>     btnClicked.append(btn.id)  # 只能用列表等来标记
#     <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=104'>105</a> pageStationList = driver.find_elements(
#     <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X30sZmlsZQ%3D%3D?line=105'>106</a>     AppiumBy.CLASS_NAME, 'android.widget.TextView')
#
# File d:\Python\Python311\Lib\site-packages\appium\webdriver\common\touch_action.py:174, in TouchAction.perform(self)
#     172     raise ValueError('Set driver to constructor as a argument when to create the instance.')
#     173 params = {'actions': self._actions}
# --> 174 self._driver.execute(Command.TOUCH_ACTION, params)
#     176 # get rid of actions so the object can be reused
#     177 self._actions = []
#
# File d:\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File d:\Python\Python311\Lib\site-packages\appium\webdriver\errorhandler.py:30, in MobileErrorHandler.check_response(self, response)
#      28 if wde.msg == 'No such context found.':
#      29     raise NoSuchContextException(wde.msg, wde.screen, wde.stacktrace) from wde
# ---> 30 raise wde
#
# File d:\Python\Python311\Lib\site-packages\appium\webdriver\errorhandler.py:26, in MobileErrorHandler.check_response(self, response)
#      24 def check_response(self, response: Dict) -> None:
#      25     try:
# ---> 26         super().check_response(response)
#      27     except WebDriverException as wde:
#      28         if wde.msg == 'No such context found.':
#
# File d:\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: Cached elements 'By.id: com.lltskb.lltskb:id/btn_query' do not exist in DOM anymore
# Stacktrace:
# io.appium.uiautomator2.common.exceptions.StaleElementReferenceException: Cached elements 'By.id: com.lltskb.lltskb:id/btn_query' do not exist in DOM anymore
# 	at io.appium.uiautomator2.model.ElementsCache.restore(ElementsCache.java:78)
# 	at io.appium.uiautomator2.model.ElementsCache.get(ElementsCache.java:153)
# 	at io.appium.uiautomator2.handler.GetSize.safeHandle(GetSize.java:42)
# 	at io.appium.uiautomator2.handler.request.SafeRequestHandler.handle(SafeRequestHandler.java:59)
# 	at io.appium.uiautomator2.server.AppiumServlet.handleRequest(AppiumServlet.java:266)
# 	at io.appium.uiautomator2.server.AppiumServlet.handleHttpRequest(AppiumServlet.java:260)
# 	at io.appium.uiautomator2.http.ServerHandler.channelRead(ServerHandler.java:68)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:366)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:352)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelRead(AbstractChannelHandlerContext.java:345)
# 	at io.netty.handler.codec.MessageToMessageDecoder.channelRead(MessageToMessageDecoder.java:102)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:366)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:352)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelRead(AbstractChannelHandlerContext.java:345)
# 	at io.netty.channel.CombinedChannelDuplexHandler$DelegatingChannelHandlerContext.fireChannelRead(CombinedChannelDuplexHandler.java:435)
# 	at io.netty.handler.codec.ByteToMessageDecoder.fireChannelRead(ByteToMessageDecoder.java:293)
# 	at io.netty.handler.codec.ByteToMessageDecoder.channelRead(ByteToMessageDecoder.java:267)
# 	at io.netty.channel.CombinedChannelDuplexHandler.channelRead(CombinedChannelDuplexHandler.java:250)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:366)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:352)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelRead(AbstractChannelHandlerContext.java:345)
# 	at io.netty.handler.timeout.IdleStateHandler.channelRead(IdleStateHandler.java:266)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:366)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:352)
# 	at io.netty.channel.AbstractChannelHandlerContext.fireChannelRead(AbstractChannelHandlerContext.java:345)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.channelRead(DefaultChannelPipeline.java:1294)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:366)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeChannelRead(AbstractChannelHandlerContext.java:352)
# 	at io.netty.channel.DefaultChannelPipeline.fireChannelRead(DefaultChannelPipeline.java:911)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:131)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:611)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:552)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:466)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:438)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$2.run(SingleThreadEventExecutor.java:140)
# 	at io.netty.util.concurrent.DefaultThreadFactory$DefaultRunnableDecorator.run(DefaultThreadFactory.java:144)
# 	at java.lang.Thread.run(Thread.java:764)

# %% [markdown]
# ## 第三部分，处理获取到的数据并生成游戏样式的时刻表
# 这部分最为重要，按照游戏中时刻表格式分为若干部分
# 车辆信息部分，如车次编号，速度等级等信息
# 停站信息部分，有四部分按顺序分别为 停站编号，停站股道，停站时刻，停站时间。这四部分会单独拆开分别生成
# 例： G7 COMMUTER 300 LPPLLPPL X1 : f#1#11:17:00#0 d#6#11:23:00#3 a#1#11:33:00#0
#
# 内容|完成度|实现原理|近期改良计划|远期优化计划
# ---|---|---|---|---
# 车辆信息|较为完善|目前为仅按照车次编号和类型生成|近期暂无|完善交路表爬取以修改速度级和编组信息立折车次信息完善
# 停站信息-停站编号|完善|依照游戏自身设置直接映射|暂无|暂无
# 停站信息-停站股道|较为完善|selenium按照web自动化12306查询获取 <br>appnium部分按照车次信息查询--检票口获得|完善车次查询部分以获得<br>停站检票口信息|使用车站大屏来获得无法离线查询的车站信息
# 停站信息-停站时刻|完善|按照到站时间和出发时间推算|近期暂无|加上线路所映射行车进路部分
# 停站信息-停站时间|完善|按照到站时间和出发时间计算|近期暂无|立折车次停站时间等按照交路表推算
# 整体上|较为完善|使用apply(lambda) 来进列映射整处理而不是按照行单个处理|暂无
#
# ### 第三部分第〇小部分--处理用函数定义
# #### 内容
# 目前按照上面输入为上面自动化爬取获取到csv样式的txt文件，输出为按照车站为单位的数据
# 1. 首先去除空行和重复值等基本操作进行数据提纯
# 2. 在统一处理如得到部分信息如停站时间和始发终到的处理，
# 3. 可以获得中心车站的停站时间信息等
# 4. 同时预先定义需要使用的处理函数
#
# #### 实现原理
# 1. 整体上以处理dataframe为主，文件→dataframe→文本
# 2. 大量使用.apply相应处理函数来处理列，尽可能少使用匿名函数来增加可读性
# 3. 由文件读出的大表来初步处理groupby 再对想到较小的表来处理
# 4.
#
#
# #### 待完善/优化的部分
# 近期暂无计划，远期计划加入进路映射以使用线路所来优化自动化

# %%
# 数据处理用
import pandas
import numpy
import time
import datetime
import random
import itertools

def dealTime(datafr: pandas.DataFrame) -> pandas.DataFrame:
    # 对于始发车和终到车进行时间处理，默认相同
    for idx, row in datafr.iterrows():
        if row["到时"] == "--:--":
            row["到时"] = row["开时"]
        elif row["开时"] == "--:--":
            row["开时"] = row["到时"]
    # 计算停站时间
    datafr["到时"] = pandas.to_datetime(datafr["到时"])
    datafr["开时"] = pandas.to_datetime(datafr["开时"])
    # 实发终到设置停站时间
    # pd["停站时间"].replace(0,10,inplace=True)

    return datafr


def stopStTime(stopTime: pandas.Timedelta) -> int:
    a = int(stopTime.seconds/60)  # 处理为数值类型的分钟时间
    # 始发或是终到的时间是随机的
    return a if a > 0 else random.randint(10, 30)


def ModtimeStr(switchTime: pandas.Timestamp) -> str:
    # 处理为仅有时分秒样式的字符串格式的时间
    return switchTime.strftime("%H:%M:%S")


def speMarType(traincode: str) -> str:  # 目前获取编组信息的方式
    til = species1[traincode[0]]  # 处理获取车辆信息字符串部分
    return "{cod} COMMUTER {speed} {mar} X1".format(cod=traincode, speed=til[0], mar=til[1])


def checkin(entrance: str) -> int:
    # 终到车
    res = 0
    if entrance == "无检票口信息":
        res = 0
    else:  # 格式类似检票口15A，替换掉其他字样
        res = int(entrance.strip("检票口AB"))
    return res


def prevnextST(stopSt: list[str], stIdx: int) -> list[str]:
    # 返回结果，获取目标车站的前后车站
    res = ["", ""]
    res1 = ["", ""]
    if stIdx == 0:  # 始发车视为始发车站和下一站
        res = [stopSt[0], stopSt[1]]
    elif stIdx == len(stopSt)-1:  # 终到车视为前一站和终到站
        res = [stopSt[len(stopSt)-2], stopSt[len(stopSt)-1]]
    else:  # 中间站
        res = [stopSt[stIdx-1], stopSt[stIdx+1]]
    # 判断并修改进路
    for k, v in route1.items():
        # 把车站名映射为线路
        if res[0] in v:
            res1[0] = k
        elif res[1] in v:
            res1[1] = k
    return res1


def arrLeaTime(t1: pandas.Timestamp, st: list[str], mark: int) -> str:
    # 选取是上一站还是下一站
    tarst = st[mark]
    useTime = station[tarst][4]
    if mark == 0:  # 进场减时间
        res = t1-datetime.timedelta(minutes=useTime)
    else:  # 离场加时间
        res = t1+datetime.timedelta(minutes=useTime)
    # 返回时分秒格式的字符串
    return res.strftime("%H:%M:%S")

# %% [markdown]
# ### 第三部分第一小部分--爬取信息整体初步处理
# #### 内容
# 1. 初步整理上面按照<b>车次检票口查询</b>到的数据
# 2. 按照车次-进站时间整理后进行分组，按照车次聚合为数据框
# 3. 获取上下站的信息等，完成初步处理
#
# #### 实现原理
# 缺省值填充等数据清洗操作
# 重分组来重新构造数据特征
# #### 待完善/优化的部分
# 暂无

# %%
# 手动建立映射关系,别的方法不会


def processTrains(fn: str, targetSt: str) -> pandas.DataFrame:
    # 处理产生初步所需信息的数据框
    trainsFrame = pandas.read_csv(filepath_or_buffer=fn,
                                  sep=",", encoding="utf8", header=None)
    trainsFrame.columns = ["车次",  "停站", "到时", "开时", "检票口", "drop1"]
    trainsFrame.drop(columns=["drop1"], inplace=True)

    trainsFrame = dealTime(trainsFrame)  # 初步处理时间
    trainsFrame.sort_values(by=["车次", "到时"], inplace=True)  # 归类排序
    # 整理为分钟样式的停站时间
    #trainsFrame["停站时间"] = trainsFrame["停站时间"].apply(lambda x: stopStTime(x))
    trainsFrame.reset_index(drop=True, inplace=True)
    # 按照车次分组为列表，同时车次不作为索引以便于操作
    tfgp = trainsFrame.groupby(by=["车次"], as_index=False).agg(list)
    # 获取目标停站的索引值，设置为一个辅助列
    tfgp["auxIdx"] = tfgp['停站'].apply(lambda x: x.index(targetSt))

    # 获取前后停站以得到更好的交路映射
    tfgp["目标前后站"] = tfgp.apply(
        lambda x: prevnextST(x["停站"], x["auxIdx"]), axis=1)
    # 获取其他信息
    tfgp["目标站到时"] = tfgp.apply(lambda x: x["到时"][x["auxIdx"]], axis=1)
    tfgp["目标站开时"] = tfgp.apply(lambda x: x["开时"][x["auxIdx"]], axis=1)
    tfgp["目标站检票口"] = tfgp.apply(lambda x: x["检票口"][x["auxIdx"]], axis=1)

    # 提取需要的信息为新的dataframe
    trainInfoNeed = tfgp[["车次", "目标站到时", "目标站开时", "目标站检票口", "目标前后站"]]
    trainInfoNeed.columns = ["车次", "到时", "开时", "检票口", "前后站"]
    # print(trainInfoNeed.head())

    return trainInfoNeed

# %% [markdown]
# ###  第三部分第二小部分 -- 处理生成最终dataframe样式的数据
#
# #### 内容
# 按照上面的函数处理数据，最终处理生成有进(离)场时间/股道 等信息的dataframe,之后生成字符串导出
# 这里分为两部分，车辆信息的trainframe和路径时刻表的stationframe,
#  'D8176 COMMUTER 200 LPPL X1 : b#2#18:08:00#0 d#0#18:16:00#14 e#0#18:36:00#0 ',
# <b>如果不做股道映射直接在等号后面写0即可，或是使用如随机数做映射等操作</b>
#
# #### 实现原理
# > 1. generateTrainInfo 即为文字版时刻表分号前的内容，生成车次信息部分
# >> 1.1. 考虑到内容只需做车次编号，速度等级和编组信息则按照车次首位ktz生成
# >> 2.1. 编组信息尚未准备开始
# > 2. generateArriveLeave 即为文字版时刻表分号后的内容，生成进场和离场信息部分
# >> 2.1. 基于停站的上一站完善进路的刻画
# >> 2.2. 本身进场和离场处理基本类似，这里使用一个mark来进行区分
# > 3. generateMainSt 即为区域核心车站生成部分
# >> 3.1. 绝大多数信息已经在前面处理完成，这里主要是处理格式问题
# >> 3.2. 车站名称的填充放在最后，防止由于数据全空导致填充失败
#
# #### 改进计划
# 1. 对于分场式车站采用进场线路--对应线路所来映射，加入线路所映射部分

# %%
def generateRoute(dataser: pandas.Series):
    # 进行中，对于分场式车站采用线路所映射进路
    s1 = "黄河南线路所"
    s2 = "大漠刘线路所"
    return None
#

def generateArriveLeave(datafr: pandas.DataFrame, mark: int) -> pandas.DataFrame:
    # 生成进场/离场信息
    # mark=0为进场，mark=1为离场
    ALStDF = pandas.DataFrame(columns=['车站名称', '股道', '到达时间', '停站时间'])  # 进场信息
    # 按照信息来映射进场/离场线路
    ALStDF['车站名称'] = datafr["前后站"].apply(lambda x: x[mark])
    # 按照信息来映射进场/离场股道
    ALStDF['股道'] = ALStDF['车站名称'].apply(lambda x: station[x][2+mark])
    # ALStDF['股道'] = 0 #不做股道映射则直接填0即可
    # 时间作差
    ALStDF['到达时间'] = datafr.apply(
        lambda x: arrLeaTime(x["到时"], x["前后站"], mark), axis=1)
    # 进程默认经过不停车
    ALStDF['停站时间'] = 0

    return ALStDF


def generateMainSt(datafr: pandas.DataFrame):
    # 生成中心停站信息
    MainStDF = pandas.DataFrame(columns=['车站名称', '股道', '到达时间', '停站时间'])  # 进场信息

    # 计算停站时长，得到整形类型的时长，非浮点数没有.0便于写入文件
    MainStDF["停站时间"] = (datafr["开时"]-datafr["到时"]
                        ).apply(lambda x: stopStTime(x))
    # 计算并规整进场离场和停站时间，将三个到时改为游戏时分秒格式 hh:mm:ss
    MainStDF["到达时间"] = datafr["到时"].apply(lambda x: ModtimeStr(x))
    # 按照相应格式处理车站检票口为对应形式
    MainStDF["股道"] = datafr["检票口"].apply(lambda x: checkin(x))
    # 填充车站为中心车站
    MainStDF["车站名称"].fillna(value="济南西", inplace=True)
    return MainStDF


def generateTrainInfo(dataser: pandas.Series) -> pandas.Series:
    # 生成车次信息
    res = dataser.apply(lambda x: speMarType(x))
    print(res.head())
    return res

# %% [markdown]
# ## 第四部分 -- 生成对应样式的字符串并写入文件
#
# ### 内容
# 1. 整合之前的数据来生成符合样式的dataframe数据合集
# 2. 生成csv长字符串并按行分割为一个个的端数据
# 3. 最终连接处理生成结果，不替换代号便于后续检查
#
# ### 实现原理
# 整合数据和字符串处理
#
# ### 改进计划
# 暂无

# %%
def generateStr(fn: str) -> list:
    # 生成游戏样式的字符串
    f = open(file=fn, encoding="utf8", mode="w")
    res = []
    for i in range(0, len(arriveStDF)):
        # format为对应顺序格式
        tf = "{train} : {arrive} {stop} {leave}".format(
            train=trainstr[i], arrive=arrivestr[i], stop=stopstr[i], leave=leavestr[i])
        print(tf)
        res.append(tf)  # 将结果写入文件
        f.write(tf+"\n")

    f.close()
    return res

# 实际运行部分
targetSt = "济南西"
at = processTrains("jinanxitest1.txt", targetSt)
# 生成dataframe格式的数据
arriveStDF = generateArriveLeave(at, mark=0)
leaveStDF = generateArriveLeave(at, mark=1)
stopStDF = generateMainSt(at)
trainDF = generateTrainInfo(at["车次"])

# 按照四部分生成需求的字符格式，使用to_csv函数来生成
arrivestr = arriveStDF.to_csv(
    sep="#", header=False, index=False).split(sep="\r\n")
leavestr = leaveStDF.to_csv(sep="#", header=False,
                            index=False).split(sep="\r\n")
stopstr = stopStDF.to_csv(sep="#", header=False, index=False).split(sep="\r\n")
trainstr = trainDF.to_csv(header=False, index=False).split(sep="\r\n")

generateStr("appnium{0}测试.txt".format(targetSt))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\z'z'x\Desktop\车次处理\appnium版,以济南西站为例.ipynb 单元格 15 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> # 实际运行部分
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> targetSt = "济南西"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=18'>19</a> at = processTrains("jinanxitest1.txt", targetSt)
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a> # 生成dataframe格式的数据
#      <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> arriveStDF = generateArriveLeave(at, mark=0)
#
# c:\Users\z'z'x\Desktop\车次处理\appnium版,以济南西站为例.ipynb 单元格 15 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> def processTrains(fn: str, targetSt: str) -> pandas.DataFrame:
#       <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     # 处理产生初步所需信息的数据框
# ----> <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     trainsFrame = pandas.read_csv(filepath_or_buffer=fn,
#       <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>                                   sep=",", encoding="utf8", header=None)
#       <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>     trainsFrame.columns = ["车次",  "停站", "到时", "开时", "检票口", "drop1"]
#       <a href='vscode-notebook-cell:/c%3A/Users/z%27z%27x/Desktop/%E8%BD%A6%E6%AC%A1%E5%A4%84%E7%90%86/appnium%E7%89%88%2C%E4%BB%A5%E6%B5%8E%E5%8D%97%E8%A5%BF%E7%AB%99%E4%B8%BA%E4%BE%8B.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     trainsFrame.drop(columns=["drop1"], inplace=True)
#
# File d:\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File d:\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File d:\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File d:\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1255, in TextFileReader.read(self, nrows)
#    1253 nrows = validate_integer("nrows", nrows)
#    1254 try:
# -> 1255     index, columns, col_dict = self._engine.read(nrows)
#    1256 except Exception:
#    1257     self.close()
#
# File d:\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File d:\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File d:\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File d:\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File d:\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 6 fields in line 57, saw 7

# %% [markdown]
# -------
#
# ## 第五部分，可视化用于分析分布如高峰期和主要类型

# %%
# 对于该车站群组（地区）时间段内的所有车次信息


def getStationProid(datafr: pandas.DataFrame, at: int) -> dict:
    # 预先分类，按照小时
    datagruop = datafr.groupby(["到时-小时", "停站", "列车类型"])
    # print(datagruop.groups)
    regionInfo = {}

    # 对于每个车站的每种类型的列车
    for sr in stationRegion:
        # 好像只能分开写两层了
        regionInfo[sr+"trainCode"] = []
        regionInfo[sr+"trainCount"] = []
        for tt in trainType:
            try:  # 查找符合条件的群组
                i = datagruop.get_group((at, sr, tt))

            except KeyError:  # 索引找不到就是0
                regionInfo[sr+"trainCount"].append(0)
                # regionInfo["trainCode"].append(None)
            else:  # 如果没问题，添加回去长度

                regionInfo[sr+"trainCode"].append(i["车次"].tolist())
                regionInfo[sr+"trainCount"].append(len(i))
        regionInfo[sr+"trainCode"] = sum(regionInfo[sr+"trainCode"], [])
    # 解包嵌套的列表
    # print(regionInfo)

    return regionInfo


def getTrainProid(datafr: pandas.DataFrame, at: int) -> dict:
    # 预先分类，数据分析用
    datagruop = datafr.groupby(["到时-小时", "停站", "列车类型"])
    # print(datagruop.groups)
    regionInfo = {}

    # 对于每个车站的每种类型的列车
    for tt in trainType:
        # 好像只能分开写两层了
        regionInfo[tt+"trainCode"] = []
        regionInfo[tt+"stationName"] = []
        regionInfo[tt+"stationCount"] = []
        for st in stationRegion:
            try:  # 查找符合条件的群组
                i = datagruop.get_group((at, st, tt))

            except KeyError:  # 索引找不到就是0
                regionInfo[tt+"stationCount"].append(0)
                # regionInfo["trainCode"].append(None)
            else:  # 如果没问题，添加回去长度
                regionInfo[tt+"trainCode"].append(i["车次"].tolist())
                regionInfo[tt+"stationName"].append(i["停站"].tolist())
                regionInfo[tt+"stationCount"].append(len(i))

        regionInfo[tt+"stationName"] = sum(regionInfo[tt+"stationName"], [])
    # 解包嵌套的列表
    # print(regionInfo)

    return regionInfo
